# %%
import pandas as pd

# %%
df = pd.DataFrame({'A': [3, 4, 5],
                   'B': ['c', 'd', 'e']},
                   index =['I', 'II', 'III'])

# %%
gfg = df.to_markdown()

# %%
print(gfg)
# Out:
# |     |   A | B   |
# |:----|----:|:----|
# | I   |   3 | c   |
# | II  |   4 | d   |
# | III |   5 | e   |

# %%
df2 = pd.DataFrame({''})
