# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
# Aula Pandas
## O r em frente a String siginifica que é uma string crua

# %%
dataset = r'https://raw.githubusercontent.com/rafaelpuyau/infinity_school/main/ds/datasets/wine_billing.csv'
